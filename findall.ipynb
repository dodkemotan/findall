# %%
import requests as rq 

from bs4 import BeautifulSoup

# %%
url = 'https://quotes.toscrape.com/'

# %%
resp = rq.get(url)

resp.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThe world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.\xe2\x8
# ...

# %%
msoup = BeautifulSoup(resp.content , 'html.parser')

# %%
msoup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %%
type(msoup)
# Out:
# bs4.BeautifulSoup

# %%
msoup.title
# Out:
# <title>Quotes to Scrape</title>

# %%
msoup.title.text
# Out:
# 'Quotes to Scrape'

# %%
msoup.h1
# Out:
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>

# %%
msoup.div
# Out:
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# ...

# %%
div1 = msoup.div

# %%
type(div1)
# Out:
# bs4.element.Tag

# %%
div1.attrs
# Out:
# {'class': ['container']}

# %%
div1.div.attrs
# Out:
# {'class': ['row', 'header-box']}

# %%
div1.div.div.a
# Out:
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>

# %%
div1.attrs['class'].append('my class')

# %%
div1
# Out:
# <div class="container my class">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# ...

# %%
msoup.div
# Out:
# <div class="container my class">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# ...

# %%
div1.attrs['myattrs']= 'At1'

# %%
div1
# Out:
# <div class="container my class" myattrs="At1">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# ...

# %%
msoup.ul
# Out:
# <ul class="pager">
# <li class="next">
# <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
# </li>
# </ul>

# %%
print(msoup.ul.prettify())
# Out:
# <ul class="pager">
#  <li class="next">
#   <a href="/page/2/">
#    Next
#    <span aria-hidden="true">
#     →
#    </span>
#   </a>
#  </li>
# </ul>

# %%
ultag = msoup.ul

# %%
ultag.li
# Out:
# <li class="next">
# <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
# </li>

# %%
list(ultag.children)
# Out:
# ['\n',
#  <li class="next">
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
#  </li>,
#  '\n']

# %%
from bs4.element import NavigableString

# %%
list(ultag.children)[0]

type(list(ultag.children)[0])
# Out:
# bs4.element.NavigableString

# %%
list(filter(lambda x : type (x) != NavigableString, ultag.children))
# Out:
# [<li class="next">
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
#  </li>]

# %%
list(div1.children)
# Out:
# ['\n',
#  <div class="row header-box">
#  <div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>
#  <div class="col-md-4">
#  <p>
#  <a href="/login">Login</a>
#  </p>
#  </div>
#  </div>,
#  '\n',
#  <div class="row">
#  <div class="col-md-8">
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# ...

# %%
list(filter(lambda x : type(x) != NavigableString , div1.children))
# Out:
# [<div class="row header-box">
#  <div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>
#  <div class="col-md-4">
#  <p>
#  <a href="/login">Login</a>
#  </p>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-8">
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# ...

# %%
def removeNavigableList(elem):
    return list(filter(lambda x: type(x) != NavigableString, elem))

# %%
removeNavigableList(div1.children)
# Out:
# [<div class="row header-box">
#  <div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>
#  <div class="col-md-4">
#  <p>
#  <a href="/login">Login</a>
#  </p>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-8">
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# ...

# %%
removeNavigableList(msoup.ul.children)
# Out:
# [<li class="next">
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
#  </li>]

# %%
msoup.ul.descendants
# Out:
# <generator object Tag.descendants at 0x000001DC171A1F20>

# %%
list(msoup.ul.descendants)
# Out:
# ['\n',
#  <li class="next">
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
#  </li>,
#  '\n',
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>,
#  'Next ',
#  <span aria-hidden="true">→</span>,
#  '→',
#  '\n',
#  '\n']

# %%
Dul = removeNavigableList(msoup.ul.descendants)

# %%
Dul
# Out:
# [<li class="next">
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
#  </li>,
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>,
#  <span aria-hidden="true">→</span>]

# %%
removeNavigableList(div1.children)
# Out:
# [<div class="row header-box">
#  <div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>
#  <div class="col-md-4">
#  <p>
#  <a href="/login">Login</a>
#  </p>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-8">
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# ...

# %%
removeNavigableList(div1.descendants)

div1_dec = removeNavigableList(div1.descendants)

# %%
div1_dec
# Out:
# [<div class="row header-box">
#  <div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>
#  <div class="col-md-4">
#  <p>
#  <a href="/login">Login</a>
#  </p>
#  </div>
#  </div>,
#  <div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>,
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>,
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>,
#  <div class="col-md-4">
#  <p>
#  <a href="/login">Login</a>
#  </p>
#  </div>,
#  <p>
#  <a href="/login">Login</a>
#  </p>,
#  <a href="/login">Login</a>,
#  <div class="row">
#  <div class="col-md-8">
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %%
div1
# Out:
# <div class="container my class" myattrs="At1">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# ...

# %%
div1_dec[0].parent
# Out:
# <div class="container my class" myattrs="At1">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# ...

# %%
ultag.nextSibling
# Out:
# '\n'

# %%
list(msoup.ul)
# Out:
# ['\n',
#  <li class="next">
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
#  </li>,
#  '\n']

# %%
msoup.a.text
# Out:
# 'Quotes to Scrape'

# %%
msoup.a.get_text()
# Out:
# 'Quotes to Scrape'

# %%
msoup.a.string
# Out:
# 'Quotes to Scrape'

# %%
msoup.ul.getText()
# Out:
# '\n\nNext →\n\n'

# %%
msoup.ul.text
# Out:
# '\n\nNext →\n\n'

# %%
msoup.ul.string

# %%
msoup.ul.li.a.string

# %%
print(f'ultag.li.a.getText() = {ultag.li.a.getText()} , {type(ultag.li.a.getText())}')

print(f'ultag.li.a.text = {ultag.li.a.text} , {type(ultag.li.a.text)}')


print(f'ultag.li.a.string = {ultag.li.a.string} , {type(ultag.li.a.string)}')
# Out:
# ultag.li.a.getText() = Next → , <class 'str'>
# ultag.li.a.text = Next → , <class 'str'>
# ultag.li.a.string = None , <class 'NoneType'>

# %%
sepUlTag = ultag.getText(separator= ' , ')

print(sepUlTag)

removeNavigableList(sepUlTag)
# Out:
#  ,
#  , Next  , → ,
#  ,
# ['\n',
#  ' ',
#  ',',
#  ' ',
#  '\n',
#  ' ',
#  ',',
#  ' ',
#  'N',
#  'e',
#  'x',
#  't',
#  ' ',
#  ' ',
#  ',',
#  ' ',
#  '→',
#  ' ',
#  ',',
#  ' ',
#  '\n',
#  ' ',
#  ',',
#  ' ',
#  '\n']

# %%
ultag.getText(separator= ' , ', strip=True)
# Out:
# 'Next , →'

# %%
msoup.stripped_strings
# Out:
# <generator object PageElement.stripped_strings at 0x000001DC17B05F20>

# %%
qSoupList  = list(msoup.stripped_strings)

# %%
len(qSoupList)
# Out:
# 102

# %%
bSoupJustString = list(msoup.strings)
bSoupJustString
# Out:
# ['\n',
#  '\n',
#  '\n',
#  '\n',
#  'Quotes to Scrape',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'Quotes to Scrape',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'Login',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  '\n',
#  'by ',
#  'Albert Einstein',
#  '\n',
#  '(about)',
#  '\n',
#  '\n',
#  '\n            Tags:\n            ',
#  '\n',
#  'change',
#  '\n',
#  'deep-thoughts',
#  '\n',
#  'thinking',
#  '\n',
#  'world',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '“It is our choices, Harry, that show what we truly are, far more than our abilities.”',
#  '\n',
#  'by ',
#  'J.K. Rowling',
#  '\n',
#  '(about)',
#  '\n',
#  '\n',
#  '\n            Tags:\n            ',
#  '\n',
#  'abilities',
#  '\n',
#  'choices',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
# ...

# %%
print(f'len(bSoupJustString) = {len(bSoupJustString)}')

print(f'len(bSoupList) = {len(qSoupList)}')
# Out:
# len(bSoupJustString) = 288
# len(bSoupList) = 102

# %%
qSoupList[1:9]
# Out:
# ['Quotes to Scrape',
#  'Login',
#  '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  'by',
#  'Albert Einstein',
#  '(about)',
#  'Tags:',
#  'change']

# %%
qSoupList[-1]
# Out:
# 'Zyte'

# %%
qSoupList[1:len(qSoupList)]
# Out:
# ['Quotes to Scrape',
#  'Login',
#  '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  'by',
#  'Albert Einstein',
#  '(about)',
#  'Tags:',
#  'change',
#  'deep-thoughts',
#  'thinking',
#  'world',
#  '“It is our choices, Harry, that show what we truly are, far more than our abilities.”',
#  'by',
#  'J.K. Rowling',
#  '(about)',
#  'Tags:',
#  'abilities',
#  'choices',
#  '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”',
#  'by',
#  'Albert Einstein',
#  '(about)',
#  'Tags:',
#  'inspirational',
#  'life',
#  'live',
#  'miracle',
#  'miracles',
#  '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”',
#  'by',
#  'Jane Austen',
#  '(about)',
#  'Tags:',
#  'aliteracy',
#  'books',
#  'classic',
#  'humor',
# ...

# %%
qSoupList[1:len(qSoupList):2]
# Out:
# ['Quotes to Scrape',
#  '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  'Albert Einstein',
#  'Tags:',
#  'deep-thoughts',
#  'world',
#  'by',
#  '(about)',
#  'abilities',
#  '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”',
#  'Albert Einstein',
#  'Tags:',
#  'life',
#  'miracle',
#  '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”',
#  'Jane Austen',
#  'Tags:',
#  'books',
#  'humor',
#  'by',
#  '(about)',
#  'be-yourself',
#  '“Try not to become a man of success. Rather become a man of value.”',
#  'Albert Einstein',
#  'Tags:',
#  'success',
#  '“It is better to be hated for what you are than to be loved for what you are not.”',
#  'André Gide',
#  'Tags:',
#  'love',
#  'by',
#  '(about)',
#  'edison',
#  'inspirational',
# ...

# %% [markdown]
# # find & find all

# %%
msoup.find('a')
# Out:
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>

# %%
msoup.a
# Out:
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>

# %%
msoup.find_all('a')
# Out:
# [<a href="/" style="text-decoration: none">Quotes to Scrape</a>,
#  <a href="/login">Login</a>,
#  <a href="/author/Albert-Einstein">(about)</a>,
#  <a class="tag" href="/tag/change/page/1/">change</a>,
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>,
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>,
#  <a class="tag" href="/tag/world/page/1/">world</a>,
#  <a href="/author/J-K-Rowling">(about)</a>,
#  <a class="tag" href="/tag/abilities/page/1/">abilities</a>,
#  <a class="tag" href="/tag/choices/page/1/">choices</a>,
#  <a href="/author/Albert-Einstein">(about)</a>,
#  <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>,
#  <a class="tag" href="/tag/life/page/1/">life</a>,
#  <a class="tag" href="/tag/live/page/1/">live</a>,
#  <a class="tag" href="/tag/miracle/page/1/">miracle</a>,
#  <a class="tag" href="/tag/miracles/page/1/">miracles</a>,
#  <a href="/author/Jane-Austen">(about)</a>,
# ...

# %%
len(msoup.find_all('a'))
# Out:
# 55

# %%
msoup.find_all(['a','p'])
# Out:
# [<a href="/" style="text-decoration: none">Quotes to Scrape</a>,
#  <p>
#  <a href="/login">Login</a>
#  </p>,
#  <a href="/login">Login</a>,
#  <a href="/author/Albert-Einstein">(about)</a>,
#  <a class="tag" href="/tag/change/page/1/">change</a>,
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>,
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>,
#  <a class="tag" href="/tag/world/page/1/">world</a>,
#  <a href="/author/J-K-Rowling">(about)</a>,
#  <a class="tag" href="/tag/abilities/page/1/">abilities</a>,
#  <a class="tag" href="/tag/choices/page/1/">choices</a>,
#  <a href="/author/Albert-Einstein">(about)</a>,
#  <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>,
#  <a class="tag" href="/tag/life/page/1/">life</a>,
#  <a class="tag" href="/tag/live/page/1/">live</a>,
#  <a class="tag" href="/tag/miracle/page/1/">miracle</a>,
#  <a class="tag" href="/tag/miracles/page/1/">miracles</a>,
#  <a href="/author/Jane-Austen">(about)</a>,
# ...

# %%
len(msoup.find_all(['a','p']))
# Out:
# 58

# %%
print(len(msoup.find_all(['p'])))

msoup.find_all(['p'])
# Out:
# 3
# [<p>
#  <a href="/login">Login</a>
#  </p>,
#  <p class="text-muted">
#                  Quotes by: <a href="https://www.goodreads.com/quotes">GoodReads.com</a>
#  </p>,
#  <p class="copyright">
#                  Made with <span class="zyte">❤</span> by <a class="zyte" href="https://www.zyte.com">Zyte</a>
#  </p>]
